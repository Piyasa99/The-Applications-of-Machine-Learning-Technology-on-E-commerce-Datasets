# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
mdata = pd.read_csv("train.csv")

# %%
mdata.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %%
mdata.tail()
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# 1995    0.8        106        6  ...       1222      1890   668    13     4
# 1996    0.2        187        4  ...        915      1965  2032    11    10
# 1997    0.7        108        8  ...        868      1632  3057     9     1
# 1998    0.1        145        5  ...        336       670   869    18    10
# 1999    0.9        168        6  ...        483       754  3919    19     4
#
#       talk_time  three_g  touch_screen  wifi  price_range
# ...

# %%
mdata.shape
# Out:
# (2000, 21)

# %%
mdata.describe()
# Out:
#        battery_power       blue  clock_speed     dual_sim           fc  \
# count    2000.000000  2000.0000  2000.000000  2000.000000  2000.000000
# mean     1238.518500     0.4950     1.522250     0.509500     4.309500
# std       439.418206     0.5001     0.816004     0.500035     4.341444
# min       501.000000     0.0000     0.500000     0.000000     0.000000
# 25%       851.750000     0.0000     0.700000     0.000000     1.000000
# 50%      1226.000000     0.0000     1.500000     1.000000     3.000000
# 75%      1615.250000     1.0000     2.200000     1.000000     7.000000
# max      1998.000000     1.0000     3.000000     1.000000    19.000000
#
#             four_g   int_memory        m_dep    mobile_wt      n_cores  ...  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000  ...
# mean      0.521500    32.046500     0.501750   140.249000     4.520500  ...
# std       0.499662    18.145715     0.288416    35.399655     2.287837  ...
# ...

# %%
mdata.dtypes
# Out:
# battery_power      int64
# blue               int64
# clock_speed      float64
# dual_sim           int64
# fc                 int64
# four_g             int64
# int_memory         int64
# m_dep            float64
# mobile_wt          int64
# n_cores            int64
# pc                 int64
# px_height          int64
# px_width           int64
# ram                int64
# sc_h               int64
# sc_w               int64
# talk_time          int64
# three_g            int64
# touch_screen       int64
# wifi               int64
# price_range        int64
# dtype: object

# %%
mdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
#  8   mobile_wt      2000 non-null   int64
#  9   n_cores        2000 non-null   int64
#  10  pc             2000 non-null   int64
#  11  px_height      2000 non-null   int64
#  12  px_width       2000 non-null   int64
#  13  ram            2000 non-null   int64
#  14  sc_h           2000 non-null   int64
#  15  sc_w           2000 non-null   int64
#  16  talk_time      2000 non-null   int64
#  17  three_g        2000 non-null   int64
# ...

# %%
mdata.columns
# Out:
# Index(['battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc', 'four_g',
#        'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc', 'px_height',
#        'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
#        'touch_screen', 'wifi', 'price_range'],
#       dtype='object')

# %%
mdata.nunique()
# Out:
# battery_power    1094
# blue                2
# clock_speed        26
# dual_sim            2
# fc                 20
# four_g              2
# int_memory         63
# m_dep              10
# mobile_wt         121
# n_cores             8
# pc                 21
# px_height        1137
# px_width         1109
# ram              1562
# sc_h               15
# sc_w               19
# talk_time          19
# three_g             2
# touch_screen        2
# wifi                2
# price_range         4
# dtype: int64

# %%
mdata.isnull().sum()
# Out:
# battery_power    0
# blue             0
# clock_speed      0
# dual_sim         0
# fc               0
# four_g           0
# int_memory       0
# m_dep            0
# mobile_wt        0
# n_cores          0
# pc               0
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# price_range      0
# dtype: int64

# %%
#Data Visualization

# %%
import matplotlib.pyplot as plt

plt.figure(figsize = (12,6))
sns.heatmap(mdata.corr())
plt.show()

# %%
#Plotting Relation between Price range and Battery Power

# %%
fig, (ax1) = plt.subplots(1, figsize=(12,6))
fig.tight_layout(pad=6.0)
fig.suptitle('Price Range and Battery Power', fontsize=35, color='navy', y=1.025, fontweight='bold')
sns.barplot(x='price_range', y='battery_power', data=mdata)

plt.show()

# %%
#Plotting Relation between Price Range and RAM

# %%
fig, (ax1) = plt.subplots(1, figsize=(12,6))
fig.tight_layout(pad=6.0)
fig.suptitle('Price Range and RAM', fontsize=35, color='navy', y=1.025, fontweight='bold')
sns.barplot(x='price_range', y='ram', data=mdata)

plt.show()

# %%
#Plotting Relation between Price Range and 3G/4G

# %%
fig, (ax1) = plt.subplots(1, figsize=(12,6))
fig.tight_layout(pad=6.0)
fig.suptitle('Price Range and 3G', fontsize=35, color='navy', y=1.025, fontweight='bold')
sns.countplot(x='three_g', hue = 'price_range', data=mdata, palette = 'pink')
plt.show()

# %%
fig, (ax1) = plt.subplots(1, figsize=(12,6))
fig.tight_layout(pad=6.0)
fig.suptitle('Price Range and 4G', fontsize=35, color='navy', y=1.025, fontweight='bold')
sns.countplot(x='four_g', hue = 'price_range', data=mdata, palette = 'ocean')
plt.show()

# %%
#Plotting Relation between Price Range and Internal Memory

# %%
fig, (ax1) = plt.subplots(1, figsize=(12,6))
fig.tight_layout(pad=6.0)
fig.suptitle('Price Range and Internal Memory', fontsize=35, color='navy', y=1.025, fontweight='bold')
sns.lineplot(x='price_range', y ='int_memory', data=mdata, hue = 'dual_sim')
plt.show()

# %%
#Plotting Relation between Price Range and Bluetooth

# %%
title = 'blue& price_range'

fig, (ax1) = plt.subplots(1, figsize=(12,6))
fig.tight_layout(pad=6.0)
fig.suptitle('Bluetooth', fontsize=35, color='navy', y=1.025, fontweight='bold')

c = ['red', 'blue']
x = mdata.blue.value_counts().sort_values().index
y = mdata.blue.value_counts().sort_values()
bar_container = ax1.bar(x, y, color=c, width=1, edgecolor="white", linewidth=0.9)
ax1.bar_label(bar_container)
ax1.set(title=title, xlabel='blue', ylabel='price_range', xticks=np.arange(0, 1.5))
plt.show()

# %%
#Front Camera

# %%
title = 'fc & price_range'

fig, (ax1) = plt.subplots(1, figsize=(12,6))
fig.tight_layout(pad=6.0)
fig.suptitle('Front Camera', fontsize=35, color='navy', y=1.025, fontweight='bold')
sns.boxplot(x='price_range', y='fc', data=mdata).set(title=title, yticks=np.arange(0, 21, 2))

plt.show()

# %%
title = 'm_dep & price_range'

fig, (ax1) = plt.subplots(1, figsize=(12,6))
fig.tight_layout(pad=6.0)
fig.suptitle('Mobile Depth', fontsize=35, color='navy', y=1.025, fontweight='bold')

x = mdata.m_dep.value_counts().sort_values().index
y = mdata.m_dep.value_counts().sort_values()
bar_container = ax1.bar(x, y, width=0.1, edgecolor="white", linewidth=0.9)
ax1.bar_label(bar_container)
ax1.set(title='mobile depth', xlabel='mobile depth', ylabel='number of samples', xticks=np.arange(0.1, 1.1, 0.1), yticks=np.arange(0, 360, 50))
# Out:
# [Text(0.5, 1.0, 'mobile depth'),
#  Text(0.5, 36.72222222222221, 'mobile depth'),
#  Text(112.59722222222221, 0.5, 'number of samples'),
# ...

# %%
title = 'm_dep & price_range'

fig, (ax1) = plt.subplots(1, figsize=(12,6))
fig.tight_layout(pad=6.0)
fig.suptitle('Mobile Width', fontsize=35, color='navy', y=1.025, fontweight='bold')

x = mdata.mobile_wt.value_counts().sort_values().index
y = mdata.mobile_wt.value_counts().sort_values()
bar_container = ax1.bar(x, y, width=0.8, edgecolor="white", linewidth=1)
ax1.bar_label(bar_container)
ax1.set(title='mobile weigth', xlabel='mobile weigth', ylabel='number of samples', xticks=np.arange(80, 210, 10), yticks=np.arange(0, 30, 5))
# Out:
# [Text(0.5, 1.0, 'mobile weigth'),
#  Text(0.5, 36.72222222222221, 'mobile weigth'),
#  Text(112.59722222222221, 0.5, 'number of samples'),
# ...

# %%
title = 'n_cores& price_range'

fig, (ax1) = plt.subplots(1, figsize=(12,6))
fig.tight_layout(pad=6.0)
fig.suptitle('Number of CPU Cores', fontsize=35, color='navy', y=1.025, fontweight='bold')

c = ['red', 'blue', 'brown', 'black', 'yellow', 'orange', 'purple', 'gray']
x = mdata.n_cores.value_counts().sort_values().index
y = mdata.n_cores.value_counts().sort_values()
bar_container = ax1.bar(x, y, color=c, width=1, edgecolor="white", linewidth=0.9)
ax1.bar_label(bar_container)
ax1.set(title=title, xlabel='n_cores', ylabel='price_range', xticks=np.arange(1, 9, 1))
# Out:
# [Text(0.5, 1.0, 'n_cores& price_range'),
#  Text(0.5, 36.72222222222221, 'n_cores'),
#  Text(112.59722222222221, 0.5, 'price_range'),
# ...

# %%
title = 'clock_speed & price_range'

fig, ax1 = plt.subplots(1, figsize=(12, 6))
fig.tight_layout(pad=6.0)
fig.suptitle('Clock Speed', fontsize=35, color='navy', y=1.025, fontweight='bold')
sns.boxplot(x='price_range', y='clock_speed', data=mdata).set(title=title, yticks=np.arange(0.5, 4))

plt.show()

# %%
title = 'px_height & price_range'

fig, (ax1) = plt.subplots(1, figsize=(12,6))
fig.tight_layout(pad=6.0)
fig.suptitle('Pixel Height', fontsize=35, color='navy', y=1.025, fontweight='bold')

ax1.scatter(mdata.px_height, mdata.price_range)
ax1.set(title=title, xlabel='px_height', ylabel='price_range', xticks=np.arange(0, 2001, 100), yticks=np.arange(0, 4))
ax1.grid()

# %%
title = 'px_width & price_range'

fig, (ax1) = plt.subplots(1, figsize=(12,6))
fig.tight_layout(pad=6.0)
fig.suptitle('Pixel Width', fontsize=35, color='navy', y=1.025, fontweight='bold')

ax1.scatter(mdata.px_width, mdata.price_range)
ax1.set(title=title, xlabel='px_width', ylabel='price_range', xticks=np.arange(500, 2001, 100), yticks=np.arange(0, 4))
ax1.grid()

# %%
title = 'sc_h & price_range'

fig, (ax1) = plt.subplots(1, figsize=(12,6))
fig.tight_layout(pad=6.0)
fig.suptitle('Screen Height', fontsize=35, color='navy', y=1.025, fontweight='bold')

x = mdata.sc_h.value_counts().sort_values().index
y = mdata.sc_h.value_counts().sort_values()
bar_container = ax1.bar(x, y, width=1, edgecolor="white", linewidth=0.9)
ax1.bar_label(bar_container)
ax1.set(title=title, xlabel='sc_h', ylabel='price_range', xticks=np.arange(5, 20, 1))
# Out:
# [Text(0.5, 1.0, 'sc_h & price_range'),
#  Text(0.5, 36.72222222222221, 'sc_h'),
#  Text(112.59722222222221, 0.5, 'price_range'),
# ...

# %%
title = 'sc_w & price_range'

fig, (ax1) = plt.subplots(1, figsize=(12,6))
fig.tight_layout(pad=6.0)
fig.suptitle('Screen Width', fontsize=35, color='navy', y=1.025, fontweight='bold')

x = mdata.sc_w.value_counts().sort_values().index
y = mdata.sc_w.value_counts().sort_values()
bar_container = ax1.bar(x, y, width=1, edgecolor="white", linewidth=0.9)
ax1.bar_label(bar_container)
ax1.set(title=title, xlabel='sc_w', ylabel='price_range', xticks=np.arange(0, 19, 1))
# Out:
# [Text(0.5, 1.0, 'sc_w & price_range'),
#  Text(0.5, 36.72222222222221, 'sc_w'),
#  Text(112.59722222222221, 0.5, 'price_range'),
# ...

# %%
title = 'wifi & price_range'

fig, (ax1) = plt.subplots(1, figsize=(10,6))
fig.tight_layout(pad=6.0)
fig.suptitle('Wifi', fontsize=35, color='navy', y=1.025, fontweight='bold')

d = mdata[['wifi']]
d = d.groupby('wifi').size()
labels = ['Dont have wifi', 'Have wifi']
explode = (0, 0.1)
ax1.pie(d, autopct='%1.1f%%', shadow=True, labels=labels, explode=explode)
# Out:
# ([<matplotlib.patches.Wedge at 0x207e28b7610>,
# ...
#  [Text(0.02418831123060699, 1.0997340249350347, 'Dont have wifi'),
#   Text(-0.026387136290265473, -1.1997098478542214, 'Have wifi')],
#  [Text(0.01319362430760381, 0.599854922691837, '49.3%'),
#   Text(-0.015392496169321524, -0.6998307445816291, '50.7%')])

# %%
title = 'talk_time & price_range'

fig, (ax1) = plt.subplots(1, figsize=(12,8))
fig.tight_layout(pad=6.0)
fig.suptitle('Talk Time', fontsize=35, color='navy', y=1.025, fontweight='bold')

d = mdata[['talk_time']]
d = d.groupby('talk_time').size()
#labels = ['Dont has 4G', 'Has 4G']
#explode = (0, 0.1)
ax1.pie(d, labels=np.arange(2, 21, 1), autopct='%1.1f%%', shadow=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x207e28130a0>,
# ...
#  [Text(1.0867261336758949, 0.17037109609860843, '2'),
#   Text(0.9863051437469176, 0.487034047493984, '3'),
#   Text(0.7667439695998647, 0.7887354975416295, '4'),
#   Text(0.46052570895294215, 0.9989574922855278, '5'),
#   Text(0.12242502501422502, 1.093166095911443, '6'),
#   Text(-0.28024780582063147, 1.063701634544538, '7'),
#   Text(-0.6353299803222909, 0.8979731711491594, '8'),
#   Text(-0.8858386827692942, 0.6521424906487553, '9'),
#   Text(-1.0466948235423696, 0.3382749567579723, '10'),
#   Text(-1.0998900790301969, -0.015550371408667798, '11'),
#   Text(-1.0401329202741958, -0.35794344268595507, '12'),
#   Text(-0.8796531203163986, -0.660462253211812, '13'),
#   Text(-0.631091323709697, -0.900957125027791, '14'),
#   Text(-0.29525699623010976, -1.0596335716544532, '15'),
#   Text(0.1000782470627587, -1.0954379692455642, '16'),
#   Text(0.4558131506215621, -1.0011165625043097, '17'),
# ...

# %%
#Data Preprocessing

# %%
x = mdata.drop(['price_range'] , axis = 1)
y = mdata['price_range']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.3, random_state = 0)

# %%
x_train
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 1719            833     1          0.6         1   0       1          27
# 1702           1424     1          2.9         1   0       0          20
# 1287            860     1          1.3         1   1       1          49
# 482            1330     1          1.3         1  14       0           3
# 768            1149     1          2.2         0   4       0          30
# ...             ...   ...          ...       ...  ..     ...         ...
# 835            1224     1          1.6         0   9       0          33
# 1216           1158     0          0.7         1   1       1          29
# 1653           1190     0          2.0         1   0       0          40
# 559            1191     0          2.4         1   2       0          13
# 684             706     0          0.5         0  13       1          31
#
#       m_dep  mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
len(x_test)
# Out:
# 600

# %%
from sklearn.linear_model import LinearRegression
clf = LinearRegression()

# %%
clf.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
clf.predict(x_test)
# Out:
# array([ 2.72463118e+00, -1.98384270e-01,  1.77434393e+00,  1.53030954e+00,
#         2.36623064e+00, -3.37478913e-01, -1.22096433e-01,  2.47614162e+00,
#         2.79973684e+00,  1.12753210e+00,  6.28103940e-01,  2.76013431e+00,
#         3.14327009e-01,  1.78692673e+00,  2.94719318e+00,  2.44733889e-01,
#         3.43961675e+00,  1.73662755e+00,  1.79264783e+00,  8.47349858e-01,
#         2.72730369e-01,  2.36667841e-01,  3.26838487e+00,  9.74049602e-01,
#         1.57401369e+00,  1.69523269e+00,  3.74348888e+00,  1.13697200e+00,
#         3.33899409e+00,  1.18630052e+00,  1.36635732e+00,  2.83519780e-01,
#         1.61883545e+00,  5.08624542e-01,  1.55046310e+00,  3.35507723e+00,
#        -5.96470202e-01, -5.63565089e-02,  3.08866237e+00,  3.22347023e+00,
#         2.39711617e+00,  1.33363883e+00,  2.94777703e+00,  2.50447596e+00,
#         1.19874977e+00,  3.44941157e+00, -3.01289647e-01,  1.20821653e+00,
# ...

# %%
y_test
# Out:
# 405     3
# 1190    0
# 1132    2
# 731     2
# 1754    2
#        ..
# 841     1
# 108     3
# 665     0
# 1214    2
# 2       2
# Name: price_range, Length: 600, dtype: int64

# %%
clf.score(x_test,y_test)
# Out:
# 0.9216228455157529

# %%
#Predicting values for test.csv

# %%
test_data = pd.read_csv("test.csv")
test_data.head()
# Out:
#    id  battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0   1           1043     1          1.8         1  14       0           5
# 1   2            841     1          0.5         1   4       1          61
# 2   3           1807     1          2.8         0   1       0          27
# 3   4           1546     0          0.5         1  18       1          25
# 4   5           1434     0          1.4         0  11       1          49
#
#    m_dep  mobile_wt  ...  pc  px_height  px_width   ram  sc_h  sc_w  \
# 0    0.1        193  ...  16        226      1412  3476    12     7
# 1    0.8        191  ...  12        746       857  3895     6     0
# 2    0.9        186  ...   4       1270      1366  2396    17    10
# 3    0.5         96  ...  20        295      1752  3893    10     0
# 4    0.5        108  ...  18        749       810  1773    15     8
#
#    talk_time  three_g  touch_screen  wifi
# 0          2        0             1     0
# ...

# %%
test_data.shape
# Out:
# (1000, 21)

# %%
test_data = test_data.drop(['id'], axis = 1)
test_data.shape
# Out:
# (1000, 20)

# %%
test_data.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0           1043     1          1.8         1  14       0           5    0.1
# 1            841     1          0.5         1   4       1          61    0.8
# 2           1807     1          2.8         0   1       0          27    0.9
# 3           1546     0          0.5         1  18       1          25    0.5
# 4           1434     0          1.4         0  11       1          49    0.5
#
#    mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        193        3  16        226      1412  3476    12     7          2
# 1        191        5  12        746       857  3895     6     0          7
# 2        186        3   4       1270      1366  2396    17    10         10
# 3         96        8  20        295      1752  3893    10     0          7
# 4        108        6  18        749       810  1773    15     8          7
#
#    three_g  touch_screen  wifi
# ...

# %%
test_pred = clf.predict(test_data)

# %%
test_data['Predicted_price'] = test_pred

# %%
test_data.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0           1043     1          1.8         1  14       0           5    0.1
# 1            841     1          0.5         1   4       1          61    0.8
# 2           1807     1          2.8         0   1       0          27    0.9
# 3           1546     0          0.5         1  18       1          25    0.5
# 4           1434     0          1.4         0  11       1          49    0.5
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        193        3  ...        226      1412  3476    12     7          2
# 1        191        5  ...        746       857  3895     6     0          7
# 2        186        3  ...       1270      1366  2396    17    10         10
# 3         96        8  ...        295      1752  3893    10     0          7
# 4        108        6  ...        749       810  1773    15     8          7
#
# ...

# %%
#Classification Using Random Forest Algorithm

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.25, random_state = 0)

# %%
from sklearn.ensemble import RandomForestClassifier
rmf = RandomForestClassifier(n_estimators = 100, random_state=0)
rmf.fit(x_train, y_train)
# Out:
# RandomForestClassifier(random_state=0)

# %%
y_pred = rmf.predict(x_test)

# %%
from sklearn.metrics import accuracy_score, classification_report

accuracy = accuracy_score(y_test, y_pred)
classification_rep = classification_report(y_test, y_pred)

print(f'Accuracy: {accuracy}')
print(f'Classification Report:\n{classification_rep}')
# Out:
# Accuracy: 0.878
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.94      0.99      0.96       124
#            1       0.84      0.80      0.82       110
#            2       0.79      0.80      0.79       125
#            3       0.93      0.91      0.92       141
#
#     accuracy                           0.88       500
#    macro avg       0.87      0.87      0.87       500
# weighted avg       0.88      0.88      0.88       500

# %%
from sklearn.metrics import cohen_kappa_score, matthews_corrcoef, mean_squared_error

# %%
cohen_kappa = cohen_kappa_score(y_test, y_pred)
matthews_corr = matthews_corrcoef(y_test, y_pred)
y_pred_prob = knn.predict_proba(x_test)[:, 1]  
mse = mean_squared_error(y_test, y_pred_prob)
rmse = mse ** 0.5
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[60], line 3
#       1 cohen_kappa = cohen_kappa_score(y_test, y_pred)
#       2 matthews_corr = matthews_corrcoef(y_test, y_pred)
# ----> 3 y_pred_prob = knn.predict_proba(x_test)[:, 1]
#       4 mse = mean_squared_error(y_test, y_pred_prob)
#       5 rmse = mse ** 0.5
#
# NameError: name 'knn' is not defined

# %%
print("Cohen's Kappa Score:", cohen_kappa)
print("Matthews Correlation Coefficient:", matthews_corr)
print("Mean Squared Error:", mse)
print("Root Mean Squared Error:", rmse)

# %%
#Classification Using Support Vector Machine (SVM) algorithm

# %%
from sklearn import svm
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
clf = svm.SVC(kernel='linear', C=1.0)

# %%
clf.fit(x_train, y_train)
# Out:
# SVC(kernel='linear')

# %%
y_pred = clf.predict(x_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
classification_rep = classification_report(y_test, y_pred)
print(f'Classification Report:\n{classification_rep}')
# Out:
# Accuracy: 0.97
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.94      0.97       105
#            1       0.91      1.00      0.95        91
#            2       0.99      0.95      0.97        92
#            3       0.98      0.99      0.99       112
#
#     accuracy                           0.97       400
#    macro avg       0.97      0.97      0.97       400
# weighted avg       0.97      0.97      0.97       400

# %%
# Calculate Cohen's Kappa score
from sklearn.svm import SVC
from sklearn.metrics import cohen_kappa_score
kappa_score = cohen_kappa_score(y_test, y_pred)
print("Cohen's Kappa Score:", kappa_score)
# Out:
# Cohen's Kappa Score: 0.9599174968476781

# %%
# Calculate Matthews Correlation Coefficient
from sklearn.metrics import matthews_corrcoef
mcc_score = matthews_corrcoef(y_test, y_pred)
print("Matthews Correlation Coefficient:", mcc_score)
# Out:
# Matthews Correlation Coefficient: 0.9604548568754908

# %%
# Calculate Mean Squared Error
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_test, y_pred)
print("Mean Squared Error:", mse)
# Out:
# Mean Squared Error: 0.03

# %%
# Calculate Root Mean Squared Error (RMSE)
from sklearn.metrics import mean_squared_error
rmse = mean_squared_error(y_test, y_pred, squared=False)
print("Root Mean Squared Error:", rmse)
# Out:
# Root Mean Squared Error: 0.17320508075688773

# %%
#Classification Using Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
clf = DecisionTreeClassifier()

# %%
clf.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = clf.predict(x_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
classification_rep = classification_report(y_test, y_pred)
print(f'Classification Report:\n{classification_rep}')
# Out:
# Accuracy: 0.825
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.91      0.87      0.89       105
#            1       0.74      0.81      0.77        91
#            2       0.76      0.71      0.73        92
#            3       0.87      0.89      0.88       112
#
#     accuracy                           0.82       400
#    macro avg       0.82      0.82      0.82       400
# weighted avg       0.83      0.82      0.82       400

# %%
# Calculate Cohen's Kappa score
from sklearn.metrics import cohen_kappa_score
kappa_score = cohen_kappa_score(y_test, y_pred)
print("Cohen's Kappa Score:", kappa_score)
# Out:
# Cohen's Kappa Score: 0.7660818713450293

# %%
# Calculate Matthews Correlation Coefficient
from sklearn.metrics import matthews_corrcoef
mcc_score = matthews_corrcoef(y_test, y_pred)
print("Matthews Correlation Coefficient:", mcc_score)
# Out:
# Matthews Correlation Coefficient: 0.7666071562568645

# %%
# Calculate Mean Squared Error
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_test, y_pred)
print("Mean Squared Error:", mse)
# Out:
# Mean Squared Error: 0.175

# %%
# Calculate Root Mean Squared Error
from sklearn.metrics import mean_squared_error
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
print("Root Mean Squared Error:", rmse)
# Out:
# Root Mean Squared Error: 0.4183300132670378

# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, cohen_kappa_score, matthews_corrcoef, mean_squared_error

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
k = 5 
knn = KNeighborsClassifier(n_neighbors=k)
knn.fit(x_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred = knn.predict(x_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='macro')
recall = recall_score(y_test, y_pred, average='macro')
f1 = f1_score(y_test, y_pred,average='macro')
cohen_kappa = cohen_kappa_score(y_test, y_pred)
matthews_corr = matthews_corrcoef(y_test, y_pred)

y_pred_prob = knn.predict_proba(x_test)[:, 1]  
mse = mean_squared_error(y_test, y_pred_prob)
rmse = mse ** 0.5

# %%
print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1-score:", f1)
print("Cohen's Kappa Score:", cohen_kappa)
print("Matthews Correlation Coefficient:", matthews_corr)
print("Mean Squared Error:", mse)
print("Root Mean Squared Error:", rmse)
# Out:
# Accuracy: 0.9425
# Precision: 0.9403626000461565
# Recall: 0.9413904483197961
# F1-score: 0.940759081791623
# Cohen's Kappa Score: 0.9231758438131503
# Matthews Correlation Coefficient: 0.9232607544947808
# Mean Squared Error: 3.3884000000000003
# Root Mean Squared Error: 1.840760712314341

# %%
#Gaussian NB

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, cohen_kappa_score, matthews_corrcoef, mean_squared_error

# %%
gnb = GaussianNB()
gnb.fit(x_train, y_train)
# Out:
# GaussianNB()

# %%
y_pred = gnb.predict(x_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='macro')
recall = recall_score(y_test, y_pred, average='macro')
f1 = f1_score(y_test, y_pred, average='macro')
cohen_kappa = cohen_kappa_score(y_test, y_pred)
matthews_corr = matthews_corrcoef(y_test, y_pred)
y_pred_prob = knn.predict_proba(x_test)[:, 1]  
mse = mean_squared_error(y_test, y_pred_prob)
rmse = mse ** 0.5

# %%
print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1-Score:", f1)
print("Cohen's Kappa:", cohen_kappa)
print("Matthews Correlation Coefficient:", matthews_corr)
print("Mean Squared Error:", mse)
print("Root Mean Squared Error:", rmse)
# Out:
# Accuracy: 0.7975
# Precision: 0.7983321971995111
# Recall: 0.7925799291288422
# F1-Score: 0.7929277885973955
# Cohen's Kappa: 0.7296756107328795
# Matthews Correlation Coefficient: 0.7313294409200803
# Mean Squared Error: 3.3884000000000003
# Root Mean Squared Error: 1.840760712314341

# %%
#MLP

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, cohen_kappa_score, matthews_corrcoef, mean_squared_error

# %%
mlp = MLPClassifier(hidden_layer_sizes=(100, 50), max_iter=1000)
mlp.fit(x_train, y_train)
# Out:
# MLPClassifier(hidden_layer_sizes=(100, 50), max_iter=1000)

# %%
y_pred = mlp.predict(x_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='macro')
recall = recall_score(y_test, y_pred, average='macro')
f1 = f1_score(y_test, y_pred, average='macro')
cohen_kappa = cohen_kappa_score(y_test, y_pred)
matthews_corr = matthews_corrcoef(y_test, y_pred)
y_pred_prob = knn.predict_proba(x_test)[:, 1]  
mse = mean_squared_error(y_test, y_pred_prob)
rmse = mse ** 0.5

# %%
print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1-Score:", f1)
print("Cohen's Kappa:", cohen_kappa)
print("Matthews Correlation Coefficient:", matthews_corr)
print("Mean Squared Error:", mse)
print("Root Mean Squared Error:", rmse)
# Out:
# Accuracy: 0.655
# Precision: 0.637102975747897
# Recall: 0.6315242275840103
# F1-Score: 0.6163800347630386
# Cohen's Kappa: 0.5339058185779061
# Matthews Correlation Coefficient: 0.5470091233997685
# Mean Squared Error: 3.3884000000000003
# Root Mean Squared Error: 1.840760712314341

# %%
#Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, cohen_kappa_score, matthews_corrcoef, mean_squared_error
from sklearn.preprocessing import StandardScaler

# %%
logreg_model = LogisticRegression(max_iter=1000)
scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %%
logreg_model = LogisticRegression(max_iter=1000)
logreg_model.fit(x_train_scaled, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
y_pred = logreg_model.predict(x_test_scaled)

# %%
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='macro')
recall = recall_score(y_test, y_pred, average='macro')
f1 = f1_score(y_test, y_pred, average='macro')
cohen_kappa = cohen_kappa_score(y_test, y_pred)
matthews_corr = matthews_corrcoef(y_test, y_pred)
y_pred_prob = knn.predict_proba(x_test)[:, 1]  
mse = mean_squared_error(y_test, y_pred_prob)
rmse = mse ** 0.5

# %%
print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1-Score:", f1)
print("Cohen's Kappa:", cohen_kappa)
print("Matthews Correlation Coefficient:", matthews_corr)
print("Mean Squared Error:", mse)
print("Root Mean Squared Error:", rmse)
# Out:
# Accuracy: 0.975
# Precision: 0.9751162260148967
# Recall: 0.9746570910973085
# F1-Score: 0.9744087955693105
# Cohen's Kappa: 0.966584241128116
# Matthews Correlation Coefficient: 0.9668750318289149
# Mean Squared Error: 3.3884000000000003
# Root Mean Squared Error: 1.840760712314341

# %%
#Adaboost

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, cohen_kappa_score, matthews_corrcoef, mean_squared_error

# %%
adaboost = AdaBoostClassifier(n_estimators=50)
adaboost.fit(x_train, y_train)
# Out:
# AdaBoostClassifier()

# %%
y_pred = adaboost.predict(x_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='macro')
recall = recall_score(y_test, y_pred, average='macro')
f1 = f1_score(y_test, y_pred, average='macro')
cohen_kappa = cohen_kappa_score(y_test, y_pred)
matthews_corr = matthews_corrcoef(y_test, y_pred)
y_pred_prob = knn.predict_proba(x_test)[:, 1]  
mse = mean_squared_error(y_test, y_pred_prob)
rmse = mse ** 0.5

# %%
print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1-Score:", f1)
print("Cohen's Kappa:", cohen_kappa)
print("Matthews Correlation Coefficient:", matthews_corr)
print("Mean Squared Error:", mse)
print("Root Mean Squared Error:", rmse)
# Out:
# Accuracy: 0.81
# Precision: 0.8198547965623018
# Recall: 0.8126911132345915
# F1-Score: 0.8098106159927806
# Cohen's Kappa: 0.7472543004181944
# Matthews Correlation Coefficient: 0.7512705861909952
# Mean Squared Error: 3.3884000000000003
# Root Mean Squared Error: 1.840760712314341

# %%
#Gradient Boost

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, cohen_kappa_score, matthews_corrcoef, mean_squared_error

# %%
gb_model = GradientBoostingClassifier(n_estimators=100)
gb_model.fit(x_train, y_train)
# Out:
# GradientBoostingClassifier()

# %%
y_pred = gb_model.predict(x_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='macro')
recall = recall_score(y_test, y_pred, average='macro')
f1 = f1_score(y_test, y_pred, average='macro')
cohen_kappa = cohen_kappa_score(y_test, y_pred)
matthews_corr = matthews_corrcoef(y_test, y_pred)
y_pred_prob = knn.predict_proba(x_test)[:, 1]  
mse = mean_squared_error(y_test, y_pred_prob)
rmse = mse ** 0.5

# %%
print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1-Score:", f1)
print("Cohen's Kappa:", cohen_kappa)
print("Matthews Correlation Coefficient:", matthews_corr)
print("Mean Squared Error:", mse)
print("Root Mean Squared Error:", rmse)
# Out:
# Accuracy: 0.905
# Precision: 0.902676303912463
# Recall: 0.9036391145086797
# F1-Score: 0.9029367915850135
# Cohen's Kappa: 0.8731081002112082
# Matthews Correlation Coefficient: 0.8732613874761723
# Mean Squared Error: 3.3884000000000003
# Root Mean Squared Error: 1.840760712314341

# %%
#XGBoost

# %%
pip install xgboost
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: There was an error checking the latest version of pip.

# %%
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, cohen_kappa_score, matthews_corrcoef, mean_squared_error

# %%
xgb_model = XGBClassifier(random_state=42)
xgb_model.fit(x_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               objective='multi:softprob', predictor=None, ...)

# %%
y_pred = xgb_model.predict(x_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='macro')
recall = recall_score(y_test, y_pred, average='macro')
f1 = f1_score(y_test, y_pred, average='macro')
cohen_kappa = cohen_kappa_score(y_test, y_pred)
matthews_corr = matthews_corrcoef(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)

# %%
print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1-Score:", f1)
print("Cohen's Kappa:", cohen_kappa)
print("Matthews Correlation Coefficient:", matthews_corr)
print("Mean Squared Error:", mse)
print("Root Mean Squared Error:", rmse)
# Out:
# Accuracy: 0.9025
# Precision: 0.9007381730135016
# Recall: 0.9025357341933429
# F1-Score: 0.9007404299962154
# Cohen's Kappa: 0.8698644421272158
# Matthews Correlation Coefficient: 0.870438445017739
# Mean Squared Error: 0.0975
# Root Mean Squared Error: 0.3122498999199199

# %%
#Bagged Decision Tree

# %%
from sklearn.ensemble import BaggingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, cohen_kappa_score, matthews_corrcoef, mean_squared_error

# %%
base_classifier = DecisionTreeClassifier(random_state=42)
bagged_model = BaggingClassifier(base_classifier, n_estimators=10, random_state=42)
bagged_model.fit(x_train, y_train)
# Out:
# BaggingClassifier(estimator=DecisionTreeClassifier(random_state=42),
#                   random_state=42)

# %%
y_pred = bagged_model.predict(x_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='macro')
recall = recall_score(y_test, y_pred, average='macro')
f1 = f1_score(y_test, y_pred, average='macro')
cohen_kappa = cohen_kappa_score(y_test, y_pred)
matthews_corr = matthews_corrcoef(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)

# %%
print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1-Score:", f1)
print("Cohen's Kappa:", cohen_kappa)
print("Matthews Correlation Coefficient:", matthews_corr)
print("Mean Squared Error:", mse)
print("Root Mean Squared Error:", rmse)
# Out:
# Accuracy: 0.8625
# Precision: 0.8599861384815792
# Recall: 0.8607983954451346
# F1-Score: 0.859771873884777
# Cohen's Kappa: 0.8164617155824003
# Matthews Correlation Coefficient: 0.8168642058678429
# Mean Squared Error: 0.1375
# Root Mean Squared Error: 0.37080992435478316

# %%
#Bagged  SVM

# %%
from sklearn.ensemble import StackingClassifier
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, cohen_kappa_score, matthews_corrcoef, mean_squared_error

# %%
svm_classifier = SVC(random_state=42)
stacked_model = StackingClassifier(estimators=[('svm', svm_classifier)], final_estimator=None)

# %%
model = LogisticRegression(max_iter=1000)

# %%
#Chi Square feature selection

# %%
import numpy as np
import pandas as pd
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

# %%
data = pd.read_csv('train.csv')

# Assuming the last column contains the labels and the rest are features
#x = data.iloc[:, :-1]  # Features
#y = data.iloc[:, -1]   # Labels
X= df.drop('price_range', axis=1)
y= df['price_range']

# %%
k = 5  # Adjust the number of features as needed

chi2_selector = SelectKBest(score_func=chi2, k=k)
x_new = chi2_selector.fit_transform(x, y)

# %%
selected_feature_indices = chi2_selector.get_support(indices=True)
selected_feature_names = x.columns[selected_feature_indices]

print("Selected Features:")
print(selected_feature_names)
# Out:
# Selected Features:
# Index(['battery_power', 'mobile_wt', 'px_height', 'px_width', 'ram'], dtype='object')

# %%
#Information Gain (IG) algorithm

# %%
import numpy as np
import pandas as pd
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import mutual_info_classif

# %%
data = pd.read_csv('train.csv')

# Assuming the last column contains the labels and the rest are features
x = data.iloc[:, :-1]  # Features
y = data.iloc[:, -1]   # Labels

# %%
k = 5  # Adjust the number of features as needed

ig_selector = SelectKBest(score_func=mutual_info_classif, k=k)
x_new = ig_selector.fit_transform(x, y)

# %%
selected_feature_indices = ig_selector.get_support(indices=True)
selected_feature_names = x.columns[selected_feature_indices]

print("Selected Features:")
print(selected_feature_names)
# Out:
# Selected Features:
# Index(['battery_power', 'px_height', 'px_width', 'ram', 'touch_screen'], dtype='object')

# %%
#Univariate Selection SelectKBest

# %%
from sklearn.feature_selection import f_classif

# %%
data = pd.read_csv('train.csv')

# Assuming the last column contains the labels and the rest are features
x = data.iloc[:, :-1]  # Features
y = data.iloc[:, -1]   # Labels

# %%
k = 5  # Adjust the number of features as needed

# Apply SelectKBest with the chosen scoring function
kbest_selector = SelectKBest(score_func=f_classif, k=k)
x_new = kbest_selector.fit_transform(x, y)

# %%
selected_feature_indices = kbest_selector.get_support(indices=True)
selected_feature_names = x.columns[selected_feature_indices]

print("Selected Features:")
print(selected_feature_names)
# Out:
# Selected Features:
# Index(['battery_power', 'mobile_wt', 'px_height', 'px_width', 'ram'], dtype='object')
